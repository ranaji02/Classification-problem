# %%
#Importing_libraries
import pandas as pd
import numpy as np

# %%
#Data Collection
da=pd.read_excel('INX_employee.xlsx')

# %%
#Data Understanding - Data Understanding/DQ Report
da.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
#Data cleaning
da.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
#splitting of the data
y=da['PerformanceRating']
X=da.drop(['PerformanceRating'],axis=1)

# %%
X.head()
# Out:
#    EmpNumber  Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0          0   32       1                    2              2              5
# 1          1   47       1                    2              2              5
# 2          2   40       1                    1              1              5
# 3          3   41       1                    0              0              3
# 4          4   60       1                    2              2              5
#
#    EmpJobRole  BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0          13                        2                10                  3
# 1          13                        2                14                  4
# 2          13                        1                 5                  4
# 3           8                        2                10                  4
# 4          13                        2                16                  4
#
# ...

# %%
y.head()
# Out:
# 0    3
# 1    3
# 2    4
# 3    3
# 4    3
# Name: PerformanceRating, dtype: int64

# %%
# Out:
# (960, 27)
# (240, 27)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['Gender'] = le.fit_transform(da['Gender'])

print(da)
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32       1           Marketing        Single
# 1     E1001006   47       1           Marketing        Single
# 2     E1001007   40       1       Life Sciences       Married
# 3     E1001009   41       1     Human Resources      Divorced
# 4     E1001010   60       1           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27       0             Medical      Divorced
# 1196   E100993   37       1       Life Sciences        Single
# 1197   E100994   50       1             Medical       Married
# 1198   E100995   34       0             Medical        Single
# 1199   E100998   24       0       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['EducationBackground'] = le.fit_transform(da['EducationBackground'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground MaritalStatus  \
# 0     E1001000   32       1                    2        Single
# 1     E1001006   47       1                    2        Single
# 2     E1001007   40       1                    1       Married
# 3     E1001009   41       1                    0      Divorced
# 4     E1001010   60       1                    2        Single
# ...        ...  ...     ...                  ...           ...
# 1195   E100992   27       0                    3      Divorced
# 1196   E100993   37       1                    1        Single
# 1197   E100994   50       1                    3       Married
# 1198   E100995   34       0                    3        Single
# 1199   E100998   24       0                    1        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['MaritalStatus'] = le.fit_transform(da['MaritalStatus'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# ...        ...  ...     ...                  ...            ...
# 1195   E100992   27       0                    3              0
# 1196   E100993   37       1                    1              2
# 1197   E100994   50       1                    3              1
# 1198   E100995   34       0                    3              2
# 1199   E100998   24       0                    1              2
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['EmpDepartment'] = le.fit_transform(da['EmpDepartment'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# ...        ...  ...     ...                  ...            ...
# 1195   E100992   27       0                    3              0
# 1196   E100993   37       1                    1              2
# 1197   E100994   50       1                    3              1
# 1198   E100995   34       0                    3              2
# 1199   E100998   24       0                    1              2
#
#       EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0                 5   Sales Executive           Travel_Rarely
# 1                 5   Sales Executive           Travel_Rarely
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['EmpJobRole'] = le.fit_transform(da['EmpJobRole'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# ...        ...  ...     ...                  ...            ...
# 1195   E100992   27       0                    3              0
# 1196   E100993   37       1                    1              2
# 1197   E100994   50       1                    3              1
# 1198   E100995   34       0                    3              2
# 1199   E100998   24       0                    1              2
#
#       EmpDepartment  EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0                 5          13           Travel_Rarely                10
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['BusinessTravelFrequency'] = le.fit_transform(da['BusinessTravelFrequency'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# ...        ...  ...     ...                  ...            ...
# 1195   E100992   27       0                    3              0
# 1196   E100993   37       1                    1              2
# 1197   E100994   50       1                    3              1
# 1198   E100995   34       0                    3              2
# 1199   E100998   24       0                    1              2
#
#       EmpDepartment  EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0                 5          13                        2                10
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['Attrition'] = le.fit_transform(da['Attrition'])

print(da)
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# ...        ...  ...     ...                  ...            ...
# 1195   E100992   27       0                    3              0
# 1196   E100993   37       1                    1              2
# 1197   E100994   50       1                    3              1
# 1198   E100995   34       0                    3              2
# 1199   E100998   24       0                    1              2
#
#       EmpDepartment  EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0                 5          13                        2                10
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['EmpNumber'] = le.fit_transform(da['EmpNumber'])

print(da)
# Out:
#       EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0             0   32       1                    2              2
# 1             1   47       1                    2              2
# 2             2   40       1                    1              1
# 3             3   41       1                    0              0
# 4             4   60       1                    2              2
# ...         ...  ...     ...                  ...            ...
# 1195       1195   27       0                    3              0
# 1196       1196   37       1                    1              2
# 1197       1197   50       1                    3              1
# 1198       1198   34       0                    3              2
# 1199       1199   24       0                    1              2
#
#       EmpDepartment  EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0                 5          13                        2                10
# ...

# %%
da.dtypes
# Out:
# EmpNumber                       int64
# Age                             int64
# Gender                          int64
# EducationBackground             int64
# MaritalStatus                   int64
# EmpDepartment                   int64
# EmpJobRole                      int64
# BusinessTravelFrequency         int64
# DistanceFromHome                int64
# EmpEducationLevel               int64
# EmpEnvironmentSatisfaction      int64
# EmpHourlyRate                   int64
# EmpJobInvolvement               int64
# EmpJobLevel                     int64
# EmpJobSatisfaction              int64
# NumCompaniesWorked              int64
# OverTime                        int64
# EmpLastSalaryHikePercent        int64
# EmpRelationshipSatisfaction     int64
# TotalWorkExperienceInYears      int64
# TrainingTimesLastYear           int64
# EmpWorkLifeBalance              int64
# ExperienceYearsAtThisCompany    int64
# ExperienceYearsInCurrentRole    int64
# YearsSinceLastPromotion         int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

da['OverTime'] = le.fit_transform(da['OverTime'])

print(da)
# Out:
#       EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0             0   32       1                    2              2
# 1             1   47       1                    2              2
# 2             2   40       1                    1              1
# 3             3   41       1                    0              0
# 4             4   60       1                    2              2
# ...         ...  ...     ...                  ...            ...
# 1195       1195   27       0                    3              0
# 1196       1196   37       1                    1              2
# 1197       1197   50       1                    3              1
# 1198       1198   34       0                    3              2
# 1199       1199   24       0                    1              2
#
#       EmpDepartment  EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0                 5          13                        2                10
# ...

# %%
#You split the data into Train Data & Test Data - Scikit-Learn
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_std,y , test_size = 0.2,random_state=1319)
print(X_train.shape)
print(X_test.shape)
# Out:
# (960, 27)
# (240, 27)

# %%
#Training the Model
from sklearn.linear_model import LogisticRegression #For Algorithm
from sklearn import neighbors #for algorithm
from sklearn.tree import DecisionTreeClassifier #for algorithm
#model = LogisticRegression()
#model = neighbors.KNeighborsClassifier()
model = DecisionTreeClassifier(criterion = 'entropy') #Calling the model/algorithm
model.fit(X_train,y_train) #Training the model/algorithm
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#Test The Model
predicted = model.predict(X_test)
predicted
# Out:
# array([3, 3, 3, 3, 2, 2, 3, 2, 2, 2, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 2, 3, 3, 3, 4, 3, 2, 2, 3, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 4, 3, 3, 4, 3, 3, 4, 3, 3,
#        3, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 4, 2, 4, 4,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 4, 2,
#        3, 2, 3, 4, 2, 3, 4, 2, 3, 3, 3, 3, 4, 3, 4, 3, 3, 2, 3, 2, 3, 3,
#        2, 3, 3, 3, 4, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 2, 2, 3,
#        3, 2, 3, 3, 3, 3, 4, 3, 2, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3,
#        3, 3, 4, 4, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 4,
#        4, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 4, 4, 3, 4])

# %%
#Evaluate the Model
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

accuracy_score(y_test,predicted)
# Out:
# 0.95

# %%
#Accuracy Improving Methods
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
X_std
# Out:
# array([[-1.73060803, -0.54145787,  0.80942721, ..., -0.68137224,
#          1.10025139, -0.41733475],
#        [-1.72772128,  1.10988772,  0.80942721, ..., -0.37083419,
#          0.8177735 , -0.41733475],
#        [-1.72483453,  0.33925978,  0.80942721, ..., -0.37083419,
#          2.23016296, -0.41733475],
#        ...,
#        [ 1.72483453,  1.44015684,  0.80942721, ...,  0.25024191,
#          1.10025139, -0.41733475],
#        [ 1.72772128, -0.32127846, -1.23544154, ...,  1.49239412,
#          0.8177735 , -0.41733475],
#        [ 1.73060803, -1.42217552, -1.23544154, ..., -0.06029614,
#         -1.15957175,  2.39615797]])

# %%
from sklearn.preprocessing import Normalizer
#fit command maintainss the equation structure
X_n = Normalizer().fit_transform(X)

# %%
X_n
# Out:
# array([[0.00000000e+00, 4.57516493e-01, 1.42973904e-02, ...,
#         0.00000000e+00, 1.14379123e-01, 0.00000000e+00],
#        [1.39373668e-02, 6.55056241e-01, 1.39373668e-02, ...,
#         1.39373668e-02, 9.75615678e-02, 0.00000000e+00],
#        [2.64813571e-02, 5.29627141e-01, 1.32406785e-02, ...,
#         1.32406785e-02, 1.58888142e-01, 0.00000000e+00],
#        ...,
#        [9.96483275e-01, 4.16241970e-02, 8.32483939e-04, ...,
#         2.49745182e-03, 6.65987151e-03, 0.00000000e+00],
#        [9.98633315e-01, 2.83418470e-02, 0.00000000e+00, ...,
#         5.83508615e-03, 5.83508615e-03, 0.00000000e+00],
#        [9.98139251e-01, 1.99794345e-02, 0.00000000e+00, ...,
#         1.66495288e-03, 0.00000000e+00, 8.32476439e-04]])
